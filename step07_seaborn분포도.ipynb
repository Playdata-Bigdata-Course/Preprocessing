# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.11.0
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\playdata\anaconda3\lib\site-packages
# Requires: matplotlib, numpy, scipy, pandas
# Required-by: missingno

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 데이터 탐색
#
# 1. total_bill : 총 계산 금액
# 2. tip
# 3. sex : 성별
# 4. smoker : 흡연여부
# 5. day
# 6. time
# 7. size : 몇인분

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(type(tips))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 계산 금액과 tip의 상관관계
# total_bill이 많을 수록 tip도 많음, 우상향 분포
sns.relplot(x='total_bill', y='tip', data=tips);

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="smoker");

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="size");

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="size", style="smoker");

# %%
sns.relplot(x="total_bill", y="tip", data=tips, hue="size", style="smoker", palette='Blues');

# %%
sns.relplot(x="total_bill", y="tip", data=tips, palette='Blues', size="size");

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
type(flights_long)
# Out:
# pandas.core.frame.DataFrame

# %%
print(flights_long.columns)
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
flights_long.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(10, 5))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# # 최종 미션
#
# flights 데이터 셋으로 seaborn 기술문서 확인 후에 2개 정도의 chart 그리기
# 이미지 화 해서 오늘 구글 디렉토리에 이름1.jpg 로 저장하기

# %%
 sns.boxplot(data = flights_long, x = 'month', y = 'passengers')
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.lmplot(data = flights_long, x = 'year', y = 'passengers')
